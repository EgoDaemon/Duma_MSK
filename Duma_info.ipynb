# %%
import pandas as pd
info = pd.read_csv('datas\Duma_info.csv')
info.head()
# Out:
#                                ФИО            Тип  Возраст      Пол  \
# 0   Данчикова Галина Иннокентьевна  mnogo_mandate       62  Женский
# 1      Кувшинова Наталья Сергеевна  mnogo_mandate       30  Женский
# 2  Пушкарев Владимир Александрович  mnogo_mandate       43  Мужской
# 3            Ганиев Фарит Глюсович  mnogo_mandate       52  Мужской
# 4         Зиннуров Ирек Хайдарович  mnogo_mandate       47  Мужской
#
#   Знак зодиака         Партия  \
# 0          Лев  Единая Россия
# 1      Близнец  Единая Россия
# 2         Рыбы  Единая Россия
# 3      Козерог  Единая Россия
# 4      Козерог  Единая Россия
#
#                                          Образование  \
# 0      Всесоюзный юридический заочный институт, 1984
# 1  федеральное государственное бюджетное образова...
# 2  Государственное образовательное учреждение выс...
# 3  Башкирский государственный университет имени 4...
# 4  Федеральное государственное автономное образов...
#
# ...

# %%
info['Партия'].unique()
# Out:
# array(['Единая Россия', 'Справедливая Россия', 'ЛДПР', 'КПРФ',
#        'Самовыдвижение', 'Гражданская платформа', 'Родина'], dtype=object)

# %%
info['Знак зодиака'].unique()
# Out:
# array(['Лев', 'Близнец', 'Рыбы', 'Козерог', 'Телец', 'Весы', 'Водолей',
#        'Овен', 'Стрелец', 'Дева', 'Рак', 'Скорпион'], dtype=object)

# %%
info.groupby('Знак зодиака')['Сумма на банковских счетах'].sum()
# Out:
# Знак зодиака
# Близнец     1.531408e+08
# Весы        1.986168e+09
# Водолей     6.052437e+08
# Дева        2.441043e+09
# Козерог     3.643890e+07
# Лев         1.856092e+08
# Овен        8.872899e+08
# Рак         3.036874e+09
# Рыбы        1.045051e+09
# Скорпион    9.428273e+07
# Стрелец     1.008112e+07
# Телец       1.198737e+08
# Name: Сумма на банковских счетах, dtype: float64
